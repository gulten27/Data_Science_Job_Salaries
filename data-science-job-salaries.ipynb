# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns  

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

import os
for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# data-science-job-salaries
#
# /kaggle/input/data-science-job-salaries/ds_salaries.csv

# %%
data = pd.read_csv('../input/data-science-job-salaries/ds_salaries.csv')
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
data.corr()
# Out:
#                Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# Unnamed: 0       1.000000   0.886550 -0.096250       0.167025      0.095000
# work_year        0.886550   1.000000 -0.087577       0.170493      0.076314
# salary          -0.096250  -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd    0.167025   0.170493 -0.083906       1.000000      0.132122
# remote_ratio     0.095000   0.076314 -0.014608       0.132122      1.000000

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
data.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
data.work_year.plot(kind = 'line', color = 'r',label = 'Speed',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.salary.plot(color = 'g',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')


plt.legend(loc='upper right')     
plt.xlabel('x axis')              
plt.ylabel('y axis')
plt.title('Line Plot')            
plt.show()

# %%
data.plot(kind='scatter', x='salary', y='remote_ratio',alpha = 0.5,color = 'g')
plt.xlabel('salary')              
plt.ylabel('remote_ratio')
plt.title('Work Year - Salary Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Work Year - Salary Scatter Plot')

# %%
data.salary_in_usd.plot(kind = 'hist',bins = 50,figsize = (5,5))
plt.show()

# %%
x = data['salary']>5000000  
data[x]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 7             7       2020               MI              FT
# 102         102       2021               MI              FT
# 136         136       2021               MI              FT
# 137         137       2021               MI              FT
# 177         177       2021               MI              FT
# 285         285       2021               SE              FT
# 384         384       2022               EX              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 7              Data Scientist  11000000             HUF          35735
# 102           BI Data Analyst  11000000             HUF          36259
# 136               ML Engineer   7000000             JPY          63711
# 137               ML Engineer   8500000             JPY          77364
# 177            Data Scientist  30400000             CLP          40038
# ...

# %%
data[np.logical_and(data['salary']>5000000, data['salary_in_usd']>50000 )]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 136         136       2021               MI              FT
# 137         137       2021               MI              FT
# 285         285       2021               SE              FT
# 384         384       2022               EX              FT
#
#                     job_title   salary salary_currency  salary_in_usd  \
# 136               ML Engineer  7000000             JPY          63711
# 137               ML Engineer  8500000             JPY          77364
# 285      Data Science Manager  7000000             INR          94665
# 384  Head of Machine Learning  6000000             INR          79039
#
#     employee_residence  remote_ratio company_location company_size
# 136                 JP            50               JP            S
# 137                 JP            50               JP            S
# 285                 IN            50               IN            L
# ...

# %%
data[(data['salary']>5000000) & (data['salary_in_usd']>50000)]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 136         136       2021               MI              FT
# 137         137       2021               MI              FT
# 285         285       2021               SE              FT
# 384         384       2022               EX              FT
#
#                     job_title   salary salary_currency  salary_in_usd  \
# 136               ML Engineer  7000000             JPY          63711
# 137               ML Engineer  8500000             JPY          77364
# 285      Data Science Manager  7000000             INR          94665
# 384  Head of Machine Learning  6000000             INR          79039
#
#     employee_residence  remote_ratio company_location company_size
# 136                 JP            50               JP            S
# 137                 JP            50               JP            S
# 285                 IN            50               IN            L
# ...

# %%
for index,value in data[['job_title']][0:5].iterrows():
    print(index," : ",value)
# Out:
# 0  :  job_title    Data Scientist
# Name: 0, dtype: object
# 1  :  job_title    Machine Learning Scientist
# Name: 1, dtype: object
# 2  :  job_title    Big Data Engineer
# Name: 2, dtype: object
# 3  :  job_title    Product Data Analyst
# Name: 3, dtype: object
# 4  :  job_title    Machine Learning Engineer
# Name: 4, dtype: object

# %%
threshold = sum(data.salary)/len(data.salary)
data["salary_level"] = ["high" if i > threshold else "low" for i in data.salary]
data.loc[:10,["salary_level","salary"]]
# Out:
#    salary_level    salary
# 0           low     70000
# 1           low    260000
# 2           low     85000
# 3           low     20000
# 4           low    150000
# 5           low     72000
# 6           low    190000
# 7          high  11000000
# 8           low    135000
# 9           low    125000
# 10          low     45000

# %%
data.shape
# Out:
# (607, 13)

# %%
print(data['job_title'].value_counts(dropna =False))
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
data.boxplot(column='salary',by = 'work_year')
# Out:
# <AxesSubplot:title={'center':'salary'}, xlabel='work_year'>

# %%
data_new = data.head()
data_new
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size salary_level
# 0                 DE             0               DE            L          low
# ...

# %%
melted = pd.melt(frame = data_new, id_vars = "job_title", value_vars = ['salary_in_usd','work_year'])
melted
# Out:
#                     job_title       variable   value
# 0              Data Scientist  salary_in_usd   79833
# 1  Machine Learning Scientist  salary_in_usd  260000
# 2           Big Data Engineer  salary_in_usd  109024
# 3        Product Data Analyst  salary_in_usd   20000
# 4   Machine Learning Engineer  salary_in_usd  150000
# 5              Data Scientist      work_year    2020
# 6  Machine Learning Scientist      work_year    2020
# 7           Big Data Engineer      work_year    2020
# 8        Product Data Analyst      work_year    2020
# 9   Machine Learning Engineer      work_year    2020

# %%
melted.pivot(index = 'job_title', columns = 'variable',values='value')
# Out:
# variable                    salary_in_usd  work_year
# job_title
# Big Data Engineer                  109024       2020
# Data Scientist                      79833       2020
# Machine Learning Engineer          150000       2020
# Machine Learning Scientist         260000       2020
# Product Data Analyst                20000       2020

# %%
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) 
conc_data_row
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5         602       2022               SE              FT
# 6         603       2022               SE              FT
# 7         604       2022               SE              FT
# 8         605       2022               SE              FT
# 9         606       2022               MI              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# ...

# %%
data1 = data['experience_level'].head()
data2= data['remote_ratio'].head()
conc_data_col = pd.concat([data1,data2],axis =1) 
conc_data_col
# Out:
#   experience_level  remote_ratio
# 0               MI             0
# 1               SE             0
# 2               SE            50
# 3               MI             0
# 4               SE            50

# %%
data['experience_level'] = data['experience_level'].astype('category')
data['salary'] = data['salary'].astype('float')
data.dtypes
# Out:
# Unnamed: 0               int64
# work_year                int64
# experience_level      category
# employment_type         object
# job_title               object
# salary                 float64
# salary_currency         object
# salary_in_usd            int64
# employee_residence      object
# remote_ratio             int64
# company_location        object
# company_size            object
# salary_level            object
# dtype: object

# %%
data1 = data.loc[:,["work_year","salary_in_usd","remote_ratio"]]
data1.plot()
# Out:
# <AxesSubplot:>

# %%
data1.plot(subplots = True)
plt.show()

# %%
data1.plot(kind = "scatter",x="work_year",y = "remote_ratio")
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object

data2= data2.set_index("date")
data2
# Out:
#             Unnamed: 0  work_year experience_level employment_type  \
# date
# 1992-01-10           0       2020               MI              FT
# 1992-02-10           1       2020               SE              FT
# 1992-03-10           2       2020               SE              FT
# 1993-03-15           3       2020               MI              FT
# 1993-03-16           4       2020               SE              FT
#
#                              job_title    salary salary_currency  \
# date
# 1992-01-10              Data Scientist   70000.0             EUR
# 1992-02-10  Machine Learning Scientist  260000.0             USD
# 1992-03-10           Big Data Engineer   85000.0             GBP
# 1993-03-15        Product Data Analyst   20000.0             USD
# 1993-03-16   Machine Learning Engineer  150000.0             USD
#
#             salary_in_usd employee_residence  remote_ratio company_location  \
# date
# ...

# %%
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# Unnamed: 0                                    4
# work_year                                  2020
# experience_level                             SE
# employment_type                              FT
# job_title             Machine Learning Engineer
# salary                                 150000.0
# salary_currency                             USD
# salary_in_usd                            150000
# employee_residence                           US
# remote_ratio                                 50
# company_location                             US
# company_size                                  L
# salary_level                                low
# Name: 1993-03-16 00:00:00, dtype: object
#             Unnamed: 0  work_year experience_level employment_type  \
# date
# 1992-03-10           2       2020               SE              FT
# 1993-03-15           3       2020               MI              FT
# 1993-03-16           4       2020               SE              FT
#
# ...

# %%
data2.resample("A").mean()
# Out:
#             Unnamed: 0  work_year         salary  salary_in_usd  remote_ratio
# date
# 1992-12-31         1.0     2020.0  138333.333333       149619.0     16.666667
# 1993-12-31         3.5     2020.0   85000.000000        85000.0     25.000000

# %%
data2.resample("M").mean()
# Out:
#             Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# date
# 1992-01-31         0.0     2020.0   70000.0        79833.0           0.0
# 1992-02-29         1.0     2020.0  260000.0       260000.0           0.0
# 1992-03-31         2.0     2020.0   85000.0       109024.0          50.0
# 1992-04-30         NaN        NaN       NaN            NaN           NaN
# 1992-05-31         NaN        NaN       NaN            NaN           NaN
# 1992-06-30         NaN        NaN       NaN            NaN           NaN
# 1992-07-31         NaN        NaN       NaN            NaN           NaN
# 1992-08-31         NaN        NaN       NaN            NaN           NaN
# 1992-09-30         NaN        NaN       NaN            NaN           NaN
# 1992-10-31         NaN        NaN       NaN            NaN           NaN
# 1992-11-30         NaN        NaN       NaN            NaN           NaN
# 1992-12-31         NaN        NaN       NaN            NaN           NaN
# ...

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#             Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# date
# 1992-01-31       0.000     2020.0   70000.0        79833.0      0.000000
# 1992-02-29       1.000     2020.0  260000.0       260000.0      0.000000
# 1992-03-31       2.000     2020.0   85000.0       109024.0     50.000000
# 1992-04-30       2.125     2020.0   85000.0       107022.0     47.916667
# 1992-05-31       2.250     2020.0   85000.0       105020.0     45.833333
# 1992-06-30       2.375     2020.0   85000.0       103018.0     43.750000
# 1992-07-31       2.500     2020.0   85000.0       101016.0     41.666667
# 1992-08-31       2.625     2020.0   85000.0        99014.0     39.583333
# 1992-09-30       2.750     2020.0   85000.0        97012.0     37.500000
# 1992-10-31       2.875     2020.0   85000.0        95010.0     35.416667
# 1992-11-30       3.000     2020.0   85000.0        93008.0     33.333333
# 1992-12-31       3.125     2020.0   85000.0        91006.0     31.250000
# ...

# %%
data= data.set_index("Unnamed: 0")
data.head()
# Out:
#             work_year experience_level employment_type  \
# Unnamed: 0
# 0                2020               MI              FT
# 1                2020               SE              FT
# 2                2020               SE              FT
# 3                2020               MI              FT
# 4                2020               SE              FT
#
#                              job_title    salary salary_currency  \
# Unnamed: 0
# 0                       Data Scientist   70000.0             EUR
# 1           Machine Learning Scientist  260000.0             USD
# 2                    Big Data Engineer   85000.0             GBP
# 3                 Product Data Analyst   20000.0             USD
# 4            Machine Learning Engineer  150000.0             USD
#
#             salary_in_usd employee_residence  remote_ratio company_location  \
# Unnamed: 0
# 0                   79833                 DE             0               DE
# ...

# %%
data["employee_residence"][1]
# Out:
# 'JP'

# %%
data.employee_residence[1]
# Out:
# 'JP'

# %%
data.loc[1,["employee_residence"]]
# Out:
# employee_residence    JP
# Name: 1, dtype: object

# %%
data[["employee_residence","company_location"]]
# Out:
#            employee_residence company_location
# Unnamed: 0
# 0                          DE               DE
# 1                          JP               JP
# 2                          GB               GB
# 3                          HN               HN
# 4                          US               US
# ...                       ...              ...
# 602                        US               US
# 603                        US               US
# 604                        US               US
# 605                        US               US
# 606                        IN               US
#
# [607 rows x 2 columns]

# %%
data.loc[1:10,"work_year":"job_title"]
# Out:
#             work_year experience_level employment_type  \
# Unnamed: 0
# 1                2020               SE              FT
# 2                2020               SE              FT
# 3                2020               MI              FT
# 4                2020               SE              FT
# 5                2020               EN              FT
# 6                2020               SE              FT
# 7                2020               MI              FT
# 8                2020               MI              FT
# 9                2020               SE              FT
# 10               2020               EN              FT
#
#                              job_title
# Unnamed: 0
# 1           Machine Learning Scientist
# 2                    Big Data Engineer
# 3                 Product Data Analyst
# 4            Machine Learning Engineer
# 5                         Data Analyst
# 6                  Lead Data Scientist
# 7                       Data Scientist
# ...

# %%
data.loc[10:1:-1,"work_year":"job_title"]
# Out:
#             work_year experience_level employment_type  \
# Unnamed: 0
# 10               2020               EN              FT
# 9                2020               SE              FT
# 8                2020               MI              FT
# 7                2020               MI              FT
# 6                2020               SE              FT
# 5                2020               EN              FT
# 4                2020               SE              FT
# 3                2020               MI              FT
# 2                2020               SE              FT
# 1                2020               SE              FT
#
#                              job_title
# Unnamed: 0
# 10                      Data Scientist
# 9                   Lead Data Engineer
# 8                Business Data Analyst
# 7                       Data Scientist
# 6                  Lead Data Scientist
# 5                         Data Analyst
# 4            Machine Learning Engineer
# ...

# %%
data.loc[1:10,"remote_ratio":]
# Out:
#             remote_ratio company_location company_size salary_level
# Unnamed: 0
# 1                      0               JP            S          low
# 2                     50               GB            M          low
# 3                      0               HN            S          low
# 4                     50               US            L          low
# 5                    100               US            L          low
# 6                    100               US            S          low
# 7                     50               HU            L         high
# 8                    100               US            L          low
# 9                     50               NZ            S          low
# 10                     0               FR            S          low

# %%
boolean = data.salary > 10000000
data[boolean]
# Out:
#             work_year experience_level employment_type        job_title  \
# Unnamed: 0
# 7                2020               MI              FT   Data Scientist
# 102              2021               MI              FT  BI Data Analyst
# 177              2021               MI              FT   Data Scientist
#
#                 salary salary_currency  salary_in_usd employee_residence  \
# Unnamed: 0
# 7           11000000.0             HUF          35735                 HU
# 102         11000000.0             HUF          36259                 HU
# 177         30400000.0             CLP          40038                 CL
#
#             remote_ratio company_location company_size salary_level
# Unnamed: 0
# 7                     50               HU            L         high
# 102                   50               US            L         high
# 177                  100               CL            L         high

# %%
first_filter = data.salary > 10000000
second_filter = data.salary_in_usd > 40000
data[first_filter & second_filter]
# Out:
#             work_year experience_level employment_type       job_title  \
# Unnamed: 0
# 177              2021               MI              FT  Data Scientist
#
#                 salary salary_currency  salary_in_usd employee_residence  \
# Unnamed: 0
# 177         30400000.0             CLP          40038                 CL
#
#             remote_ratio company_location company_size salary_level
# Unnamed: 0
# 177                  100               CL            L         high

# %%
data.salary[data.salary_in_usd<15000]
# Out:
# Unnamed: 0
# 15       8000.0
# 18     423000.0
# 21     450000.0
# 38      10000.0
# 50     450000.0
# 77     400000.0
# 96      12000.0
# 113     12000.0
# 124      8760.0
# 127    700000.0
# 153     13400.0
# 176     58000.0
# 179    420000.0
# 184     12000.0
# 185      4000.0
# 196      9272.0
# 205     69600.0
# 213    435000.0
# 238      4000.0
# 247    108000.0
# 521     10000.0
# Name: salary, dtype: float64

# %%
def div(n):
    return n/10000
data.salary.apply(div)
# Out:
# Unnamed: 0
# 0       7.0
# 1      26.0
# 2       8.5
# 3       2.0
# 4      15.0
#        ...
# 602    15.4
# 603    12.6
# 604    12.9
# 605    15.0
# 606    20.0
# Name: salary, Length: 607, dtype: float64

# %%
data.salary.apply(lambda n : n/10000)
# Out:
# Unnamed: 0
# 0       7.0
# 1      26.0
# 2       8.5
# 3       2.0
# 4      15.0
#        ...
# 602    15.4
# 603    12.6
# 604    12.9
# 605    15.0
# 606    20.0
# Name: salary, Length: 607, dtype: float64

# %%
data["salary_rate"] = data.salary / data.salary_in_usd
data.head()
# Out:
#             work_year experience_level employment_type  \
# Unnamed: 0
# 0                2020               MI              FT
# 1                2020               SE              FT
# 2                2020               SE              FT
# 3                2020               MI              FT
# 4                2020               SE              FT
#
#                              job_title    salary salary_currency  \
# Unnamed: 0
# 0                       Data Scientist   70000.0             EUR
# 1           Machine Learning Scientist  260000.0             USD
# 2                    Big Data Engineer   85000.0             GBP
# 3                 Product Data Analyst   20000.0             USD
# 4            Machine Learning Engineer  150000.0             USD
#
#             salary_in_usd employee_residence  remote_ratio company_location  \
# Unnamed: 0
# 0                   79833                 DE             0               DE
# ...

# %%
print(data.index.name)
data.index.name = "index_name"
data.head()
# Out:
# Unnamed: 0
#             work_year experience_level employment_type  \
# index_name
# 0                2020               MI              FT
# 1                2020               SE              FT
# 2                2020               SE              FT
# 3                2020               MI              FT
# 4                2020               SE              FT
#
#                              job_title    salary salary_currency  \
# index_name
# 0                       Data Scientist   70000.0             EUR
# 1           Machine Learning Scientist  260000.0             USD
# 2                    Big Data Engineer   85000.0             GBP
# 3                 Product Data Analyst   20000.0             USD
# 4            Machine Learning Engineer  150000.0             USD
#
#             salary_in_usd employee_residence  remote_ratio company_location  \
# index_name
# 0                   79833                 DE             0               DE
# ...

# %%
data1 = data.set_index(["salary","salary_in_usd"]) 
data1.head(100)
# Out:
#                         work_year experience_level employment_type  \
# salary   salary_in_usd
# 70000.0  79833               2020               MI              FT
# 260000.0 260000              2020               SE              FT
# 85000.0  109024              2020               SE              FT
# 20000.0  20000               2020               MI              FT
# 150000.0 150000              2020               SE              FT
# ...                           ...              ...             ...
# 120000.0 89294               2021               MI              FT
# 12000.0  12000               2021               EN              PT
# 450000.0 450000              2021               MI              FT
# 70000.0  70000               2021               EN              FT
# 81000.0  95746               2021               MI              FT
#
#                                                 job_title salary_currency  \
# salary   salary_in_usd
# ...

# %%
data.groupby("salary_currency").mean()
# Out:
#                    work_year        salary  salary_in_usd  remote_ratio  \
# salary_currency
# AUD              2022.000000  1.205000e+05   87064.000000     75.000000
# BRL              2021.000000  8.580000e+04   15904.000000      0.000000
# CAD              2021.333333  1.230278e+05   97222.888889     80.555556
# CHF              2022.000000  1.150000e+05  122346.000000      0.000000
# CLP              2021.000000  3.040000e+07   40038.000000    100.000000
# CNY              2021.000000  2.695000e+05   40283.500000     25.000000
# DKK              2020.500000  2.400000e+05   37252.500000     50.000000
# EUR              2021.052632  5.728104e+04   65751.473684     67.368421
# GBP              2021.590909  6.165582e+04   81670.977273     45.454545
# HUF              2020.500000  1.100000e+07   35997.000000     50.000000
# INR              2021.000000  2.064259e+06   27765.555556     59.259259
# JPY              2020.666667  6.650000e+06   60921.333333     66.666667
# ...

# %%
data.groupby("salary_currency").salary.max()
# Out:
# salary_currency
# AUD      121000.0
# BRL      102000.0
# CAD      250000.0
# CHF      115000.0
# CLP    30400000.0
# CNY      299000.0
# DKK      300000.0
# EUR      148000.0
# GBP      140000.0
# HUF    11000000.0
# INR     7000000.0
# JPY     8500000.0
# MXN      720000.0
# PLN      180000.0
# SGD      160000.0
# TRY      250000.0
# USD      600000.0
# Name: salary, dtype: float64

# %%
data.groupby("salary_currency")[["salary","salary_in_usd"]].min()
# Out:
#                      salary  salary_in_usd
# salary_currency
# AUD                120000.0          86703
# BRL                 69600.0          12901
# CAD                 66500.0          52396
# CHF                115000.0         122346
# CLP              30400000.0          40038
# CNY                240000.0          37236
# DKK                180000.0          28609
# EUR                  8760.0          10354
# GBP                 28500.0          37300
# HUF              11000000.0          35735
# INR                400000.0           5409
# JPY               4450000.0          41689
# MXN                 58000.0           2859
# PLN                110000.0          28476
# SGD                120000.0          89294
# TRY                108000.0          12103
# USD                  4000.0           4000
